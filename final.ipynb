# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('data.csv')

# %%
clean_df = df.drop(columns='Person ID', axis=1)
clean_df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   27           1             6.1                 6
# 1         1   28           0             6.2                 6
# 2         1   28           0             6.2                 6
# 3         1   28           2             5.9                 4
# 4         1   28           2             5.9                 4
# ..      ...  ...         ...             ...               ...
# 369       0   59           0             8.1                 9
# 370       0   59           0             8.0                 9
# 371       0   59           0             8.1                 9
# 372       0   59           0             8.1                 9
# 373       0   59           0             8.1                 9
#
#      Physical Activity Level  Stress Level  BMI Category  \
# 0                         42             6             1
# 1                         60             8             0
# ...

# %%
clean_df['Stress Level'].describe()
# Out:
# count    374.000000
# mean       5.385027
# std        1.774526
# min        3.000000
# 25%        4.000000
# 50%        5.000000
# 75%        7.000000
# max        8.000000
# Name: Stress Level, dtype: float64

# %%
Categorical_Col = []
Numerical_Col = []
for col in clean_df.columns:
    if clean_df[col].dtype == 'object':
        Categorical_Col.append(col)  
    else:
        Numerical_Col.append(col)

# %%
LE = LabelEncoder()
for col in Categorical_Col:
    clean_df[col] = LE.fit_transform(clean_df[col])

# %%
X = clean_df.iloc[:,:-1]
y = clean_df['Sleep Disorder']

# %%
X
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   27           1             6.1                 6
# 1         1   28           0             6.2                 6
# 2         1   28           0             6.2                 6
# 3         1   28           2             5.9                 4
# 4         1   28           2             5.9                 4
# ..      ...  ...         ...             ...               ...
# 369       0   59           0             8.1                 9
# 370       0   59           0             8.0                 9
# 371       0   59           0             8.1                 9
# 372       0   59           0             8.1                 9
# 373       0   59           0             8.1                 9
#
#      Physical Activity Level  Stress Level  BMI Category  \
# 0                         42             6             1
# 1                         60             8             0
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 369    1
# 370    1
# 371    1
# 372    1
# 373    1
# Name: Sleep Disorder, Length: 374, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)
y_pred_tree = decision_tree.predict(X_test)
acc_tree = accuracy_score(y_test, y_pred_tree)

# %%
print("Decision Tree Accuracy: ", acc_tree*100," % ")
print(classification_report(y_test, y_pred_tree))
# Out:
# Decision Tree Accuracy:  90.42553191489363  %
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        55
#            1       0.89      0.77      0.83        22
#            2       0.74      0.82      0.78        17
#
#     accuracy                           0.90        94
#    macro avg       0.87      0.86      0.86        94
# weighted avg       0.91      0.90      0.90        94

# %% [markdown]
# ### model variable  = decision_tree

# %%
import joblib

# %%
joblib.dump(decision_tree,'model')
# Out:
# ['model']

# %%
loaded = joblib.load('model')

# %%
o = [[1,27,1,6.1,6,42,6,1,126,83,77,4200],[1,28,2,5.9,4,30,8,2,140,90,85,3000]]

# %%
loaded.predict(o)
# Out:
# C:\Users\rushi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0, 1], dtype=int64)
